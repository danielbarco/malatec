# %%
import cv2
import numpy as np
import os
import time
import poly_yolo as yolo #or "import poly_yolo_lite as yolo" for the lite version
import sys
sys.path.insert(0, os.path.dirname(os.path.abspath('.'))) # to make imports relative to project root work

# %%
#load pretrained model
#if you want to detect more objects, lower the score and vice versa
trained_model = yolo.YOLO(model_path='../data/weights/poly_yolo.h5', iou=0.5, score=0.3)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-5-f74bcf78e191> in <module>
#       1 #load pretrained model
#       2 #if you want to detect more objects, lower the score and vice versa
# ----> 3 trained_model = yolo.YOLO(model_path='../data/weights/poly_yolo.h5', iou=0.5, score=0.3)
#
# /tf/Notebooks/poly_yolo.py in __init__(self, **kwargs)
#     844         self.anchors = self._get_anchors()
#     845         self.sess = tf.compat.v1.keras.backend.get_session()
# --> 846         self.boxes, self.scores, self.classes, self.polygons = self.generate()
#     847
#     848     def _get_class(self):
#
# /tf/Notebooks/poly_yolo.py in generate(self)
#     870             self.yolo_model = load_model(model_path, compile=False)
#     871         except:
# --> 872             self.yolo_model = yolo_body(Input(shape=(None, None, 3)), anchors_per_level, num_classes)
#     873             self.yolo_model.load_weights(self.model_path)  # make sure model, anchors and classes match
#     874         else:
#
# /tf/Notebooks/poly_yolo.py in yolo_body(inputs, num_anchors, num_classes)
#     411 def yolo_body(inputs, num_anchors, num_classes):
#     412     """Create Poly-YOLO model CNN body in Keras."""
# --> 413     tiny, small, medium, big = darknet_body(inputs)
#     414
#     415     base = 6
#
# /tf/Notebooks/poly_yolo.py in darknet_body(x)
#     403     x = resblock_body(x, base * 64, 8)
#     404     medium = x
# --> 405     x = resblock_body(x, base * 128, 8)
#     406     big = x
#     407     return tiny, small, medium, big
#
# /tf/Notebooks/poly_yolo.py in resblock_body(x, num_filters, num_blocks)
#     361         y = compose(
#     362             DarknetConv2D_BN_Leaky(num_filters // 2, (1, 1)),
# --> 363             DarknetConv2D_BN_Leaky(num_filters, (3, 3)))(x)
#     364         y = squeeze_excite_block(y)
#     365         x = Add()([x, y])
#
# /tf/Notebooks/poly_yolo.py in <lambda>(*a, **kw)
#      59     # return lambda x: reduce(lambda v, f: f(v), funcs, x)
#      60     if funcs:
# ---> 61         return reduce(lambda f, g: lambda *a, **kw: g(f(*a, **kw)), funcs)
#      62     else:
#      63         raise ValueError('Composition of empty sequence not supported.')
#
# /tf/Notebooks/poly_yolo.py in <lambda>(*a, **kw)
#      59     # return lambda x: reduce(lambda v, f: f(v), funcs, x)
#      60     if funcs:
# ---> 61         return reduce(lambda f, g: lambda *a, **kw: g(f(*a, **kw)), funcs)
#      62     else:
#      63         raise ValueError('Composition of empty sequence not supported.')
#
# /tf/Notebooks/poly_yolo.py in <lambda>(*a, **kw)
#      59     # return lambda x: reduce(lambda v, f: f(v), funcs, x)
#      60     if funcs:
# ---> 61         return reduce(lambda f, g: lambda *a, **kw: g(f(*a, **kw)), funcs)
#      62     else:
#      63         raise ValueError('Composition of empty sequence not supported.')
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     950     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     951       return self._functional_construction_call(inputs, args, kwargs,
# --> 952                                                 input_list)
#     953
#     954     # Maintains info about the `Layer.call` stack.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1089         # Check input assumptions set after layer building, e.g. input shape.
#    1090         outputs = self._keras_tensor_symbolic_call(
# -> 1091             inputs, input_masks, args, kwargs)
#    1092
#    1093         if outputs is None:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     820       return nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     821     else:
# --> 822       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     823
#     824   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     860           # overridden).
#     861           # TODO(kaftan): do we maybe_build here, or have we already done it?
# --> 862           self._maybe_build(inputs)
#     863           outputs = call_fn(inputs, *args, **kwargs)
#     864
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in _maybe_build(self, inputs)
#    2708         # operations.
#    2709         with tf_utils.maybe_init_scope(self):
# -> 2710           self.build(input_shapes)  # pylint:disable=not-callable
#    2711       # We must set also ensure that the layer is marked as built, and the build
#    2712       # shape is stored since user defined build functions may not be calling
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/convolutional.py in build(self, input_shape)
#     203         constraint=self.kernel_constraint,
#     204         trainable=True,
# --> 205         dtype=self.dtype)
#     206     if self.use_bias:
#     207       self.bias = self.add_weight(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, **kwargs)
#     637         synchronization=synchronization,
#     638         aggregation=aggregation,
# --> 639         caching_device=caching_device)
#     640     if regularizer is not None:
#     641       # TODO(fchollet): in the future, this should be handled at the
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     808         dtype=dtype,
#     809         initializer=initializer,
# --> 810         **kwargs_for_getter)
#     811
#     812     # If we set an initializer and the variable processed it, tracking will not
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     140       synchronization=synchronization,
#     141       aggregation=aggregation,
# --> 142       shape=variable_shape if variable_shape else None)
#     143
#     144
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     258   def __call__(cls, *args, **kwargs):
#     259     if cls is VariableV1:
# --> 260       return cls._variable_v1_call(*args, **kwargs)
#     261     elif cls is Variable:
#     262       return cls._variable_v2_call(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     219         synchronization=synchronization,
#     220         aggregation=aggregation,
# --> 221         shape=shape)
#     222
#     223   def _variable_v2_call(cls,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/variables.py in <lambda>(**kwargs)
#     197                         shape=None):
#     198     """Call on Variable class. Useful to force the signature."""
# --> 199     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     200     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     201       previous_getter = _make_getter(getter, previous_getter)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2616         synchronization=synchronization,
#    2617         aggregation=aggregation,
# -> 2618         shape=shape)
#    2619   else:
#    2620     return variables.RefVariable(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     262       return cls._variable_v2_call(*args, **kwargs)
#     263     else:
# --> 264       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     265
#     266
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1583           aggregation=aggregation,
#    1584           shape=shape,
# -> 1585           distribute_strategy=distribute_strategy)
#    1586
#    1587   def _init_from_args(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1710           with ops.name_scope("Initializer"), device_context_manager(None):
#    1711             if init_from_fn:
# -> 1712               initial_value = initial_value()
#    1713             if isinstance(initial_value, trackable.CheckpointInitialValue):
#    1714               self._maybe_initialize_trackable()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/initializers/initializers_v2.py in __call__(self, shape, dtype, **kwargs)
#     408     """
#     409     return super(VarianceScaling, self).__call__(
# --> 410         shape, dtype=_get_dtype(dtype), **kwargs)
#     411
#     412
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops_v2.py in __call__(self, shape, dtype, **kwargs)
#     598     else:
#     599       limit = math.sqrt(3.0 * scale)
# --> 600       return self._random_generator.random_uniform(shape, -limit, limit, dtype)
#     601
#     602   def get_config(self):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops_v2.py in random_uniform(self, shape, minval, maxval, dtype)
#    1080       op = random_ops.random_uniform
#    1081     return op(
# -> 1082         shape=shape, minval=minval, maxval=maxval, dtype=dtype, seed=self.seed)
#    1083
#    1084   def truncated_normal(self, shape, mean, stddev, dtype):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/random_ops.py in random_uniform(shape, minval, maxval, dtype, seed, name)
#     306           result = math_ops.multiply(result, maxval)
#     307       else:
# --> 308         result = math_ops.add(result * (maxval - minval), minval, name=name)
#     309     # TODO(b/132092188): C++ shape inference inside functional ops does not
#     310     # cross FuncGraph boundaries since that information is only available in
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#    1162     with ops.name_scope(None, op_name, [x, y]) as name:
#    1163       try:
# -> 1164         return func(x, y, name=name)
#    1165       except (TypeError, ValueError) as e:
#    1166         # Even if dispatching the op failed, the RHS may be a tensor aware
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py in _mul_dispatch(x, y, name)
#    1494     return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1495   else:
# -> 1496     return multiply(x, y, name=name)
#    1497
#    1498
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py in multiply(x, y, name)
#     516   """
#     517
# --> 518   return gen_math_ops.mul(x, y, name)
#     519
#     520
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_math_ops.py in mul(x, y, name)
#    6066       return _result
#    6067     except _core._NotOkStatusException as e:
# -> 6068       _ops.raise_from_not_ok_status(e, name)
#    6069     except _core._FallbackException:
#    6070       pass
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6860   message = e.message + (" name: " + name if name is not None else "")
#    6861   # pylint: disable=protected-access
# -> 6862   six.raise_from(core._status_to_exception(e.code, message), None)
#    6863   # pylint: enable=protected-access
#    6864
#
# /usr/local/lib/python3.6/dist-packages/six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[3,3,384,768] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Mul]

# %%
#helper function
def translate_color(cls):
    if cls == 0: return (230, 25, 75)
    if cls == 1: return (60, 180, 75)
    if cls == 2: return (255, 225, 25)
    if cls == 3: return (0, 130, 200)
    if cls == 4: return (245, 130, 48)
    if cls == 5: return (145, 30, 180)
    if cls == 7: return (70, 240, 240)
    if cls == 8: return (240, 50, 230)
    if cls == 9: return (210, 245, 60)
    if cls == 10: return (250, 190, 190)
    if cls == 11: return (0, 128, 128)
    if cls == 12: return (230, 190, 255)
    if cls == 13: return (170, 110, 40)
    if cls == 14: return (255, 250, 200)
    if cls == 15: return (128, 0, 128)
    if cls == 16: return (170, 255, 195)
    if cls == 17: return (128, 128, 0)
    if cls == 18: return (255, 215, 180)
    if cls == 19: return (80, 80, 128)

# %%
dir_imgs_name = 'D:/data-shared/cityscapes/leftImg8bit_demoVideo/leftImg8bit/demoVideo/stuttgart_01'  #path_where_are_images_to_clasification
out_path       = 'poly_yolo_predict/' #path, where the images will be saved. The path must exist
list_of_imgs = [root+"/"+name for root, dirs, files in os.walk(dir_imgs_name) for name in files]    
list_of_imgs.sort()

#browse all images
total_boxes = 0
imgs        = 0
for im in range (0, len(list_of_imgs)):
    imgs    += 1
    img     = cv2.imread(list_of_imgs[im])
    overlay = img.copy()
    boxes   = []
    scores  = []
    classes = []
    
    #realize prediciction using poly-yolo
    startx = time.time()
    box, scores, classes, polygons = trained_model.detect_image(img)
    print('Prediction speed: ', 1.0/(time.time() - startx), 'fps')
    
    
    #example, hw to reshape reshape y1,x1,y2,x2 into x1,y1,x2,y2
    for k in range (0, len(box)):
        boxes.append((box[k][1], box[k][0], box[k][3], box[k][2]))
        cv2.rectangle(img, (box[k][1],box[k][0]), (box[k][3],box[k][2]), translate_color(classes[k]), 3, 1)
    total_boxes += len(boxes)
    
    #browse all boxes
    for b in range(0, len(boxes)):
        f              = translate_color(classes[b])    
        points_to_draw = []
        offset         = len(polygons[b])//3
        
        #filter bounding polygon vertices
        for dst in range(0, len(polygons[b])//3):
            if polygons[b][dst+offset*2] > 0.3: 
                points_to_draw.append([int(polygons[b][dst]), int(polygons[b][dst+offset])])
        
        points_to_draw = np.asarray(points_to_draw)
        points_to_draw = points_to_draw.astype(np.int32)
        if points_to_draw.shape[0]>0:
            cv2.polylines(img, [points_to_draw],True,f, thickness=2)
            cv2.fillPoly(overlay, [points_to_draw], f)
    img = cv2.addWeighted(overlay, 0.4, img, 1 - 0.4, 0)
    cv2.imwrite(out_path+str(imgs)+'.jpg', img)
    
print('total boxes: ', total_boxes)
print('imgs: ', imgs)
# Out:
# Prediction speed:  6.2500245870126925 fps
# Prediction speed:  20.408550144270304 fps
# Prediction speed:  17.857372763732663 fps
# Prediction speed:  18.51871605810411 fps
# Prediction speed:  17.545131307046827 fps
# Prediction speed:  18.18179611334839 fps
# Prediction speed:  16.95024409168795 fps
# Prediction speed:  17.54505791457339 fps
# Prediction speed:  18.182111382286514 fps
# Prediction speed:  17.85813307900608 fps
# Prediction speed:  18.86827354764411 fps
# Prediction speed:  18.18163848297925 fps
# Prediction speed:  17.5439571011486 fps
# Prediction speed:  13.514536579078797 fps
# Prediction speed:  20.407656452225023 fps
# Prediction speed:  13.69868346707688 fps
# Prediction speed:  20.000495922941205 fps
# Prediction speed:  20.408649448218142 fps
# Prediction speed:  22.72928961215609 fps
# Prediction speed:  20.833912011166248 fps
# Prediction speed:  20.000782043517862 fps
# Prediction speed:  21.278030022473732 fps
# Prediction speed:  23.256210078069554 fps
# Prediction speed:  19.607889336119566 fps
# Prediction speed:  21.739241306747797 fps
# Prediction speed:  18.182663129237547 fps
# Prediction speed:  22.727688489590673 fps
# Prediction speed:  17.857752913276535 fps
# Prediction speed:  20.40845084128884 fps
# Prediction speed:  21.27619511403295 fps
# Prediction speed:  18.52018792610124 fps
# Prediction speed:  15.384996863800927 fps
# Prediction speed:  19.231281350585515 fps
# Prediction speed:  20.408550144270304 fps
# Prediction speed:  19.607706008573658 fps
# Prediction speed:  16.666881246150485 fps
# Prediction speed:  20.000782043517862 fps
# Prediction speed:  19.609447758681952 fps
# Prediction speed:  16.949353635522364 fps
# Prediction speed:  19.608531009527727 fps
# Prediction speed:  20.409145982453495 fps
# Prediction speed:  18.868952610600758 fps
# Prediction speed:  17.543516814455412 fps
# Prediction speed:  19.231369528237437 fps
# Prediction speed:  19.230752301654256 fps
# Prediction speed:  20.83442945419142 fps
# Prediction speed:  18.181717297822168 fps
# Prediction speed:  19.607981001178075 fps
# Prediction speed:  19.60917272493513 fps
# Prediction speed:  17.24199111242657 fps
# Prediction speed:  17.242487276673764 fps
# Prediction speed:  16.950381093248627 fps
# Prediction speed:  19.606972732669842 fps
# Prediction speed:  20.833187634109514 fps
# Prediction speed:  17.857981010771915 fps
# Prediction speed:  18.517489680139512 fps
# Prediction speed:  19.60825600149599 fps
# Prediction speed:  21.739128631995772 fps
# Prediction speed:  18.518143728173 fps
# Prediction speed:  21.740931568198548 fps
# Prediction speed:  20.833912011166248 fps
# Prediction speed:  22.22194907441747 fps
# Prediction speed:  18.868782840279277 fps
# Prediction speed:  19.60825600149599 fps
# Prediction speed:  19.231369528237437 fps
# Prediction speed:  18.868782840279277 fps
# Prediction speed:  18.18250548383461 fps
# Prediction speed:  20.409841170974776 fps
# Prediction speed:  17.54469096141619 fps
# Prediction speed:  18.181323230440455 fps
# Prediction speed:  15.384714702818492 fps
# Prediction speed:  18.18242666215824 fps
# Prediction speed:  18.51920665477473 fps
# Prediction speed:  19.23092864806375 fps
# Prediction speed:  17.240715392615062 fps
# Prediction speed:  19.232868672046955 fps
# Prediction speed:  19.231104997707472 fps
# Prediction speed:  17.544984522713964 fps
# Prediction speed:  15.873085074174993 fps
# Prediction speed:  19.231722246931355 fps
# Prediction speed:  19.2311931737422 fps
# Prediction speed:  18.51871605810411 fps
# Prediction speed:  17.241565851512945 fps
# Prediction speed:  16.39328525922886 fps
# Prediction speed:  16.667808504973355 fps
# Prediction speed:  16.393477479167643 fps
# Prediction speed:  18.51920665477473 fps
# Prediction speed:  18.86971661485444 fps
# Prediction speed:  17.857752913276535 fps
# Prediction speed:  18.18163848297925 fps
# Prediction speed:  19.2311931737422 fps
# Prediction speed:  16.39366970361424 fps
# Prediction speed:  17.240006740954176 fps
# Prediction speed:  16.394823144966793 fps
# Prediction speed:  18.182663129237547 fps
# Prediction speed:  19.231545885967126 fps
# Prediction speed:  16.3939260098888 fps
# Prediction speed:  17.857524821608 fps
# Prediction speed:  17.544103868290723 fps
# Prediction speed:  18.18321490967577 fps
# Prediction speed:  18.181953746450787 fps
# Prediction speed:  17.241282355891165 fps
# Prediction speed:  16.66655010728761 fps
# Prediction speed:  17.544103868290723 fps
# Prediction speed:  18.51920665477473 fps
# Prediction speed:  18.51896135319025 fps
# Prediction speed:  19.607797671918096 fps
# Prediction speed:  20.002021993953093 fps
# Prediction speed:  18.18234784116525 fps
# Prediction speed:  17.24177847934754 fps
# Prediction speed:  19.608164333866277 fps
# Prediction speed:  18.867679407649987 fps
# Prediction speed:  19.610364593560934 fps
# Prediction speed:  19.60825600149599 fps
# Prediction speed:  18.868867725058145 fps
# Prediction speed:  17.241565851512945 fps
# Prediction speed:  18.51945196285781 fps
# Prediction speed:  19.608072667093644 fps
# Prediction speed:  18.18179611334839 fps
# Prediction speed:  12.820619098709166 fps
# Prediction speed:  17.241636726875107 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  17.24177847934754 fps
# Prediction speed:  18.519043119663024 fps
# Prediction speed:  18.51912488685785 fps
# Prediction speed:  18.51896135319025 fps
# Prediction speed:  10.7527232361454 fps
# Prediction speed:  12.195544907115297 fps
# Prediction speed:  10.869564315997886 fps
# Prediction speed:  12.500607996948094 fps
# Prediction speed:  12.345483658283884 fps
# Prediction speed:  12.820775854427188 fps
# Prediction speed:  15.62537579769697 fps
# Prediction speed:  13.513709266884469 fps
# Prediction speed:  17.856916605643637 fps
# Prediction speed:  20.409543227238 fps
# Prediction speed:  14.084676552761659 fps
# Prediction speed:  14.706123250399708 fps
# Prediction speed:  16.665954090491876 fps
# Prediction speed:  19.230752301654256 fps
# Prediction speed:  18.181244419013932 fps
# Prediction speed:  13.698638727039949 fps
# Prediction speed:  19.231281350585515 fps
# Prediction speed:  19.231545885967126 fps
# Prediction speed:  13.698415031238875 fps
# Prediction speed:  18.86827354764411 fps
# Prediction speed:  14.92539267947249 fps
# Prediction speed:  18.86827354764411 fps
# Prediction speed:  14.492702344095534 fps
# Prediction speed:  15.3850532972394 fps
# Prediction speed:  13.698772948027473 fps
# Prediction speed:  20.40894736586007 fps
# Prediction speed:  14.285338664686709 fps
# Prediction speed:  14.493002812696526 fps
# Prediction speed:  14.925445791535743 fps
# Prediction speed:  22.222420023100316 fps
# Prediction speed:  16.12883676216112 fps
# Prediction speed:  20.000877418862597 fps
# Prediction speed:  17.242132870726262 fps
# Prediction speed:  18.18226902085564 fps
# Prediction speed:  20.83246330742295 fps
# Prediction speed:  18.181323230440455 fps
# Prediction speed:  13.513839888391635 fps
# Prediction speed:  14.492852576838686 fps
# Prediction speed:  13.157444993067276 fps
# Prediction speed:  20.833808525645484 fps
# Prediction speed:  15.384771134187003 fps
# Prediction speed:  19.60761434608624 fps
# Prediction speed:  20.833912011166248 fps
# Prediction speed:  20.832980678488056 fps
# Prediction speed:  20.40924529219989 fps
# Prediction speed:  20.000400551234794 fps
# Prediction speed:  20.001354309230763 fps
# Prediction speed:  19.608806025273612 fps
# Prediction speed:  19.608897698903217 fps
# Prediction speed:  20.833601557688105 fps
# Prediction speed:  20.40845084128884 fps
# Prediction speed:  17.85858929924807 fps
# Prediction speed:  20.000305180437934 fps
# Prediction speed:  20.407656452225023 fps
# Prediction speed:  19.608072667093644 fps
# Prediction speed:  19.231634066044915 fps
# Prediction speed:  20.000400551234794 fps
# Prediction speed:  19.231104997707472 fps
# Prediction speed:  19.607064389158463 fps
# Prediction speed:  17.24177847934754 fps
# Prediction speed:  20.40884805901301 fps
# Prediction speed:  20.408649448218142 fps
# Prediction speed:  19.608164333866277 fps
# Prediction speed:  18.181874929557928 fps
# Prediction speed:  20.83473993234416 fps
# Prediction speed:  20.001735837899446 fps
# Prediction speed:  17.857144681775026 fps
# Prediction speed:  17.534275896089564 fps
# Prediction speed:  18.52018792610124 fps
# Prediction speed:  18.867679407649987 fps
# Prediction speed:  18.868358427840732 fps
# Prediction speed:  19.608622680585878 fps
# Prediction speed:  20.40825223822499 fps
# Prediction speed:  18.868782840279277 fps
# Prediction speed:  19.231545885967126 fps
# Prediction speed:  18.51855253165675 fps
# Prediction speed:  15.873205216509358 fps
# Prediction speed:  20.000686669082725 fps
# Prediction speed:  17.241282355891165 fps
# Prediction speed:  19.231722246931355 fps
# Prediction speed:  20.832980678488056 fps
# Prediction speed:  19.60724770470652 fps
# Prediction speed:  21.27695062623967 fps
# Prediction speed:  20.40845084128884 fps
# Prediction speed:  21.27727443361099 fps
# Prediction speed:  18.868867725058145 fps
# Prediction speed:  20.408748753132375 fps
# Prediction speed:  21.739128631995772 fps
# Prediction speed:  20.83401549771508 fps
# Prediction speed:  18.868528190525033 fps
# Prediction speed:  21.276842692639374 fps
# Prediction speed:  21.27619511403295 fps
# Prediction speed:  20.40924529219989 fps
# Prediction speed:  19.232251349232186 fps
# Prediction speed:  20.000686669082725 fps
# Prediction speed:  20.407755747475978 fps
# Prediction speed:  19.23092864806375 fps
# Prediction speed:  18.86818866821116 fps
# Prediction speed:  19.231281350585515 fps
# Prediction speed:  19.22969429111115 fps
# Prediction speed:  19.60871435250117 fps
# Prediction speed:  19.231545885967126 fps
# Prediction speed:  19.23066412966232 fps
# Prediction speed:  19.232868672046955 fps
# Prediction speed:  19.23013511468931 fps
# Prediction speed:  17.85813307900608 fps
# Prediction speed:  20.40825223822499 fps
# Prediction speed:  18.521905401168464 fps
# Prediction speed:  19.606972732669842 fps
# Prediction speed:  19.231104997707472 fps
# Prediction speed:  20.40845084128884 fps
# Prediction speed:  19.607797671918096 fps
# Prediction speed:  19.23084047445473 fps
# Prediction speed:  17.857220708446867 fps
# Prediction speed:  19.231457706697967 fps
# Prediction speed:  19.999923706345726 fps
# Prediction speed:  18.517816698381022 fps
# Prediction speed:  19.608072667093644 fps
# Prediction speed:  18.51920665477473 fps
# Prediction speed:  18.867679407649987 fps
# Prediction speed:  19.231986794442662 fps
# Prediction speed:  18.86827354764411 fps
# Prediction speed:  19.608072667093644 fps
# Prediction speed:  19.608072667093644 fps
# Prediction speed:  18.86784915811587 fps
# Prediction speed:  19.230487788104003 fps
# Prediction speed:  19.60926440199351 fps
# Prediction speed:  19.231986794442662 fps
# Prediction speed:  20.41013912341059 fps
# Prediction speed:  20.000877418862597 fps
# Prediction speed:  19.988200477508947 fps
# Prediction speed:  20.833394593842822 fps
# Prediction speed:  19.2327804806471 fps
# Prediction speed:  16.949901597475076 fps
# Prediction speed:  20.408152938142575 fps
# Prediction speed:  19.99935152249168 fps
# Prediction speed:  20.40795434087669 fps
# Prediction speed:  19.608806025273612 fps
# Prediction speed:  19.60752268445583 fps
# Prediction speed:  20.834532945880834 fps
# Prediction speed:  20.001545071745692 fps
# Prediction speed:  19.99935152249168 fps
# Prediction speed:  19.999923706345726 fps
# Prediction speed:  19.60917272493513 fps
# Prediction speed:  20.83349807525146 fps
# Prediction speed:  20.000400551234794 fps
# Prediction speed:  20.409344602912768 fps
# Prediction speed:  19.232427723135476 fps
# Prediction speed:  19.9996376103262 fps
# Prediction speed:  19.23084047445473 fps
# Prediction speed:  19.231281350585515 fps
# Prediction speed:  19.607889336119566 fps
# Prediction speed:  16.129270928269555 fps
# Prediction speed:  17.856612513197778 fps
# Prediction speed:  20.411033032916123 fps
# Prediction speed:  20.000686669082725 fps
# Prediction speed:  19.60825600149599 fps
# Prediction speed:  18.86784915811587 fps
# Prediction speed:  20.409344602912768 fps
# Prediction speed:  19.231369528237437 fps
# Prediction speed:  20.408351539273742 fps
# Prediction speed:  19.608072667093644 fps
# Prediction speed:  20.002403548094808 fps
# Prediction speed:  19.231104997707472 fps
# Prediction speed:  20.000591295557175 fps
# Prediction speed:  19.608806025273612 fps
# Prediction speed:  19.231104997707472 fps
# Prediction speed:  20.833601557688105 fps
# Prediction speed:  20.407855043693193 fps
# Prediction speed:  18.181480855343295 fps
# Prediction speed:  18.868018911636234 fps
# Prediction speed:  20.001735837899446 fps
# Prediction speed:  20.000209810550608 fps
# Prediction speed:  19.60752268445583 fps
# Prediction speed:  19.231281350585515 fps
# Prediction speed:  19.231545885967126 fps
# Prediction speed:  19.231545885967126 fps
# Prediction speed:  18.181717297822168 fps
# Prediction speed:  19.60963111879938 fps
# Prediction speed:  19.2303114497797 fps
# Prediction speed:  20.000591295557175 fps
# Prediction speed:  18.181717297822168 fps
# Prediction speed:  19.231281350585515 fps
# Prediction speed:  20.833705041152776 fps
# Prediction speed:  20.40845084128884 fps
# Prediction speed:  17.857600851516764 fps
# Prediction speed:  19.607797671918096 fps
# Prediction speed:  19.231810428626453 fps
# Prediction speed:  16.3935415534823 fps
# Prediction speed:  18.18234784116525 fps
# Prediction speed:  19.608347669982795 fps
# Prediction speed:  18.181244419013932 fps
# Prediction speed:  20.001926607692123 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  19.608164333866277 fps
# Prediction speed:  19.60825600149599 fps
# Prediction speed:  19.607981001178075 fps
# Prediction speed:  19.609081048733962 fps
# Prediction speed:  19.231634066044915 fps
# Prediction speed:  18.869377049770335 fps
# Prediction speed:  19.608806025273612 fps
# Prediction speed:  18.18116560827066 fps
# Prediction speed:  19.608439339326704 fps
# Prediction speed:  18.51871605810411 fps
# Prediction speed:  19.23092864806375 fps
# Prediction speed:  18.181717297822168 fps
# Prediction speed:  17.544324023608247 fps
# Prediction speed:  20.000019073504518 fps
# Prediction speed:  19.999446884193762 fps
# Prediction speed:  18.182111382286514 fps
# Prediction speed:  15.87344550663427 fps
# Prediction speed:  18.520024373658785 fps
# Prediction speed:  18.18250548383461 fps
# Prediction speed:  20.001449690033382 fps
# Prediction speed:  20.002021993953093 fps
# Prediction speed:  20.000305180437934 fps
# Prediction speed:  16.66568920782126 fps
# Prediction speed:  20.000400551234794 fps
# Prediction speed:  18.51912488685785 fps
# Prediction speed:  18.518225487425827 fps
# Prediction speed:  19.60752268445583 fps
# Prediction speed:  17.241424102536698 fps
# Prediction speed:  18.181874929557928 fps
# Prediction speed:  18.172815542393664 fps
# Prediction speed:  17.544544184451155 fps
# Prediction speed:  18.18282077737413 fps
# Prediction speed:  19.231457706697967 fps
# Prediction speed:  19.60752268445583 fps
# Prediction speed:  16.94976460366531 fps
# Prediction speed:  19.231722246931355 fps
# Prediction speed:  18.86759453356245 fps
# Prediction speed:  17.240573657622257 fps
# Prediction speed:  18.519043119663024 fps
# Prediction speed:  19.609539438312037 fps
# Prediction speed:  20.00106817228093 fps
# Prediction speed:  18.867764282501124 fps
# Prediction speed:  18.51863429451943 fps
# Prediction speed:  20.407755747475978 fps
# Prediction speed:  17.857144681775026 fps
# Prediction speed:  17.85767688207294 fps
# Prediction speed:  19.229958782832753 fps
# Prediction speed:  17.54535148815126 fps
# Prediction speed:  18.182111382286514 fps
# Prediction speed:  17.54542488308081 fps
# Prediction speed:  17.544470796889573 fps
# Prediction speed:  18.182111382286514 fps
# Prediction speed:  19.23066412966232 fps
# Prediction speed:  16.66734486266531 fps
# Prediction speed:  16.949148158924125 fps
# Prediction speed:  18.18163848297925 fps
# Prediction speed:  17.856384450660094 fps
# Prediction speed:  18.868528190525033 fps
# Prediction speed:  18.867934034494237 fps
# Prediction speed:  18.518061969642115 fps
# Prediction speed:  20.000877418862597 fps
# Prediction speed:  19.608439339326704 fps
# Prediction speed:  20.40884805901301 fps
# Prediction speed:  19.231457706697967 fps
# Prediction speed:  17.54373695503959 fps
# Prediction speed:  19.608806025273612 fps
# Prediction speed:  18.518389008097344 fps
# Prediction speed:  20.409841170974776 fps
# Prediction speed:  17.241636726875107 fps
# Prediction speed:  20.408152938142575 fps
# Prediction speed:  18.5187978224108 fps
# Prediction speed:  19.999923706345726 fps
# Prediction speed:  18.519533733663017 fps
# Prediction speed:  19.999446884193762 fps
# Prediction speed:  16.129022830488335 fps
# Prediction speed:  19.608806025273612 fps
# Prediction speed:  17.54359019403628 fps
# Prediction speed:  19.230487788104003 fps
# Prediction speed:  19.60752268445583 fps
# Prediction speed:  18.18226902085564 fps
# Prediction speed:  18.867764282501124 fps
# Prediction speed:  19.231457706697967 fps
# Prediction speed:  18.181874929557928 fps
# Prediction speed:  18.182663129237547 fps
# Prediction speed:  18.519288423413677 fps
# Prediction speed:  19.999828340096414 fps
# Prediction speed:  19.231898611130216 fps
# Prediction speed:  18.86929216040885 fps
# Prediction speed:  19.230399618537604 fps
# Prediction speed:  18.518470769516057 fps
# Prediction speed:  18.181559668819627 fps
# Prediction speed:  19.60917272493513 fps
# Prediction speed:  18.181323230440455 fps
# Prediction speed:  18.51887958743951 fps
# Prediction speed:  19.23092864806375 fps
# Prediction speed:  19.230575958478905 fps
# Prediction speed:  18.182978428244432 fps
# Prediction speed:  16.39309304379773 fps
# Prediction speed:  17.85744879234663 fps
# Prediction speed:  18.868443308801037 fps
# Prediction speed:  17.85843722324409 fps
# Prediction speed:  19.2311931737422 fps
# Prediction speed:  18.86818866821116 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  19.230752301654256 fps
# Prediction speed:  17.54292979990631 fps
# Prediction speed:  19.608897698903217 fps
# Prediction speed:  19.607706008573658 fps
# Prediction speed:  17.241565851512945 fps
# Prediction speed:  18.51855253165675 fps
# Prediction speed:  18.868697956264143 fps
# Prediction speed:  19.230487788104003 fps
# Prediction speed:  18.518225487425827 fps
# Prediction speed:  18.868443308801037 fps
# Prediction speed:  19.608439339326704 fps
# Prediction speed:  18.51855253165675 fps
# Prediction speed:  18.86784915811587 fps
# Prediction speed:  18.517244424038005 fps
# Prediction speed:  18.868358427840732 fps
# Prediction speed:  18.867934034494237 fps
# Prediction speed:  18.519043119663024 fps
# Prediction speed:  18.18179611334839 fps
# Prediction speed:  19.231104997707472 fps
# Prediction speed:  19.609722800144 fps
# Prediction speed:  18.868018911636234 fps
# Prediction speed:  18.181086798210632 fps
# Prediction speed:  19.608989373389996 fps
# Prediction speed:  19.595797066917086 fps
# Prediction speed:  18.867339915881335 fps
# Prediction speed:  20.409841170974776 fps
# Prediction speed:  15.15244917939214 fps
# Prediction speed:  20.407855043693193 fps
# Prediction speed:  19.607889336119566 fps
# Prediction speed:  18.519288423413677 fps
# Prediction speed:  18.18179611334839 fps
# Prediction speed:  18.51863429451943 fps
# Prediction speed:  18.51945196285781 fps
# Prediction speed:  15.873385433421008 fps
# Prediction speed:  17.240786260985374 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  19.231281350585515 fps
# Prediction speed:  18.868697956264143 fps
# Prediction speed:  17.544324023608247 fps
# Prediction speed:  19.23092864806375 fps
# Prediction speed:  17.857068655750545 fps
# Prediction speed:  18.181953746450787 fps
# Prediction speed:  16.949490622689012 fps
# Prediction speed:  18.181244419013932 fps
# Prediction speed:  18.869971296687872 fps
# Prediction speed:  19.23092864806375 fps
# Prediction speed:  19.999828340096414 fps
# Prediction speed:  18.51887958743951 fps
# Prediction speed:  18.181086798210632 fps
# Prediction speed:  18.86861307301273 fps
# Prediction speed:  20.83567142232643 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  20.00011444157281 fps
# Prediction speed:  19.229782454209936 fps
# Prediction speed:  18.86827354764411 fps
# Prediction speed:  19.608897698903217 fps
# Prediction speed:  19.23092864806375 fps
# Prediction speed:  19.609356079909112 fps
# Prediction speed:  18.868952610600758 fps
# Prediction speed:  19.230046948356808 fps
# Prediction speed:  18.520269703405734 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  19.607889336119566 fps
# Prediction speed:  19.60752268445583 fps
# Prediction speed:  19.609356079909112 fps
# Prediction speed:  18.518143728173 fps
# Prediction speed:  19.609356079909112 fps
# Prediction speed:  20.40795434087669 fps
# Prediction speed:  19.229341646799927 fps
# Prediction speed:  18.518225487425827 fps
# Prediction speed:  19.22960612882077 fps
# Prediction speed:  19.231016822481326 fps
# Prediction speed:  18.86827354764411 fps
# Prediction speed:  20.000495922941205 fps
# Prediction speed:  19.608897698903217 fps
# Prediction speed:  20.001545071745692 fps
# Prediction speed:  19.608347669982795 fps
# Prediction speed:  19.60871435250117 fps
# Prediction speed:  20.00011444157281 fps
# Prediction speed:  20.000400551234794 fps
# Prediction speed:  19.230487788104003 fps
# Prediction speed:  20.002212769204355 fps
# Prediction speed:  20.000495922941205 fps
# Prediction speed:  18.868782840279277 fps
# Prediction speed:  17.242061991285045 fps
# Prediction speed:  18.51896135319025 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  18.867339915881335 fps
# Prediction speed:  19.231104997707472 fps
# Prediction speed:  17.857600851516764 fps
# Prediction speed:  18.182663129237547 fps
# Prediction speed:  18.182111382286514 fps
# Prediction speed:  17.241920234150832 fps
# Prediction speed:  18.868443308801037 fps
# Prediction speed:  19.231016822481326 fps
# Prediction speed:  17.857372763732663 fps
# Prediction speed:  16.9495591171027 fps
# Prediction speed:  19.230752301654256 fps
# Prediction speed:  18.51969727743975 fps
# Prediction speed:  16.667146166715014 fps
# Prediction speed:  19.232427723135476 fps
# Prediction speed:  18.519043119663024 fps
# Prediction speed:  18.86818866821116 fps
# Prediction speed:  16.66701370538003 fps
# Prediction speed:  17.241636726875107 fps
# Prediction speed:  19.23092864806375 fps
# Prediction speed:  19.60761434608624 fps
# Prediction speed:  18.18116560827066 fps
# Prediction speed:  18.507357840346998 fps
# Prediction speed:  18.18179611334839 fps
# Prediction speed:  18.18242666215824 fps
# Prediction speed:  18.18203256402698 fps
# Prediction speed:  18.867934034494237 fps
# Prediction speed:  18.181559668819627 fps
# Prediction speed:  19.608531009527727 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  18.518143728173 fps
# Prediction speed:  18.18289960246756 fps
# Prediction speed:  17.85813307900608 fps
# Prediction speed:  20.409046673673558 fps
# Prediction speed:  17.857220708446867 fps
# Prediction speed:  18.18179611334839 fps
# Prediction speed:  17.24177847934754 fps
# Prediction speed:  17.545131307046827 fps
# Prediction speed:  17.857144681775026 fps
# Prediction speed:  18.182111382286514 fps
# Prediction speed:  18.51863429451943 fps
# Prediction speed:  18.181717297822168 fps
# Prediction speed:  17.857144681775026 fps
# Prediction speed:  17.857904977626017 fps
# Prediction speed:  16.667146166715014 fps
# Prediction speed:  16.9495591171027 fps
# Prediction speed:  18.86861307301273 fps
# Prediction speed:  20.40894736586007 fps
# Prediction speed:  19.999923706345726 fps
# Prediction speed:  19.230575958478905 fps
# Prediction speed:  18.18163848297925 fps
# Prediction speed:  18.86929216040885 fps
# Prediction speed:  18.50948133961157 fps
# Prediction speed:  18.5187978224108 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  19.999828340096414 fps
# Prediction speed:  20.408748753132375 fps
# Prediction speed:  18.51912488685785 fps
# Prediction speed:  19.231104997707472 fps
# Prediction speed:  17.857296735766074 fps
# Prediction speed:  18.517816698381022 fps
# Prediction speed:  19.2311931737422 fps
# Prediction speed:  18.5197790504113 fps
# Prediction speed:  17.241565851512945 fps
# Prediction speed:  17.85699263037342 fps
# Prediction speed:  17.242487276673764 fps
# Prediction speed:  20.001545071745692 fps
# Prediction speed:  20.408649448218142 fps
# Prediction speed:  18.869546830784735 fps
# Prediction speed:  18.868358427840732 fps
# Prediction speed:  19.999923706345726 fps
# Prediction speed:  18.868443308801037 fps
# Prediction speed:  18.518061969642115 fps
# Prediction speed:  19.231104997707472 fps
# Prediction speed:  19.999542246805266 fps
# Prediction speed:  18.520269703405734 fps
# Prediction speed:  18.51920665477473 fps
# Prediction speed:  17.241565851512945 fps
# Prediction speed:  18.520433260181306 fps
# Prediction speed:  20.000305180437934 fps
# Prediction speed:  18.86818866821116 fps
# Prediction speed:  18.867934034494237 fps
# Prediction speed:  19.23092864806375 fps
# Prediction speed:  18.51912488685785 fps
# Prediction speed:  18.181559668819627 fps
# Prediction speed:  18.519942598520807 fps
# Prediction speed:  19.230752301654256 fps
# Prediction speed:  18.51871605810411 fps
# Prediction speed:  19.230487788104003 fps
# Prediction speed:  18.5187978224108 fps
# Prediction speed:  18.86708530507224 fps
# Prediction speed:  16.129270928269555 fps
# Prediction speed:  18.51871605810411 fps
# Prediction speed:  19.608531009527727 fps
# Prediction speed:  20.83349807525146 fps
# Prediction speed:  19.23013511468931 fps
# Prediction speed:  20.000400551234794 fps
# Prediction speed:  19.6098144823459 fps
# Prediction speed:  19.231369528237437 fps
# Prediction speed:  18.518061969642115 fps
# Prediction speed:  18.86784915811587 fps
# Prediction speed:  19.99935152249168 fps
# Prediction speed:  19.609906165405096 fps
# Prediction speed:  18.86759453356245 fps
# Prediction speed:  19.231281350585515 fps
# Prediction speed:  19.231016822481326 fps
# Prediction speed:  18.868782840279277 fps
# Prediction speed:  18.868443308801037 fps
# Prediction speed:  19.608806025273612 fps
# Prediction speed:  19.60871435250117 fps
# Prediction speed:  18.86818866821116 fps
# Prediction speed:  18.518143728173 fps
# Prediction speed:  18.86827354764411 fps
# Prediction speed:  20.001163550354548 fps
# Prediction speed:  20.000495922941205 fps
# Prediction speed:  18.867934034494237 fps
# Prediction speed:  19.607797671918096 fps
# Prediction speed:  18.870225985396207 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  18.51789845474614 fps
# Prediction speed:  19.608439339326704 fps
# Prediction speed:  18.868782840279277 fps
# Prediction speed:  20.833291113462177 fps
# Prediction speed:  19.231898611130216 fps
# Prediction speed:  18.1821902012294 fps
# Prediction speed:  20.000209810550608 fps
# Prediction speed:  20.000305180437934 fps
# Prediction speed:  18.5187978224108 fps
# Prediction speed:  20.000782043517862 fps
# Prediction speed:  18.182741952964125 fps
# Prediction speed:  19.99916080181572 fps
# Prediction speed:  20.40845084128884 fps
# Prediction speed:  20.001449690033382 fps
# Prediction speed:  18.518143728173 fps
# Prediction speed:  20.00097279511695 fps
# Prediction speed:  18.518470769516057 fps
# Prediction speed:  19.60871435250117 fps
# Prediction speed:  20.40944391459213 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  18.86827354764411 fps
# Prediction speed:  19.607797671918096 fps
# Prediction speed:  20.40894736586007 fps
# Prediction speed:  19.608072667093644 fps
# Prediction speed:  18.18203256402698 fps
# Prediction speed:  20.408748753132375 fps
# Prediction speed:  18.51871605810411 fps
# Prediction speed:  20.40974185542931 fps
# Prediction speed:  17.85820911409436 fps
# Prediction speed:  19.60724770470652 fps
# Prediction speed:  19.607981001178075 fps
# Prediction speed:  19.999923706345726 fps
# Prediction speed:  20.833808525645484 fps
# Prediction speed:  20.000495922941205 fps
# Prediction speed:  19.608439339326704 fps
# Prediction speed:  19.606972732669842 fps
# Prediction speed:  18.519533733663017 fps
# Prediction speed:  20.409841170974776 fps
# Prediction speed:  19.607981001178075 fps
# Prediction speed:  20.000591295557175 fps
# Prediction speed:  19.231369528237437 fps
# Prediction speed:  20.833187634109514 fps
# Prediction speed:  19.231016822481326 fps
# Prediction speed:  20.001163550354548 fps
# Prediction speed:  18.52067860076126 fps
# Prediction speed:  20.001163550354548 fps
# Prediction speed:  18.868018911636234 fps
# Prediction speed:  18.517980211833166 fps
# Prediction speed:  18.51912488685785 fps
# Prediction speed:  20.00011444157281 fps
# Prediction speed:  20.4100398049654 fps
# Prediction speed:  19.231369528237437 fps
# Prediction speed:  18.868103789541873 fps
# Prediction speed:  20.409344602912768 fps
# Prediction speed:  20.833705041152776 fps
# Prediction speed:  20.000495922941205 fps
# Prediction speed:  19.60761434608624 fps
# Prediction speed:  18.5193701927747 fps
# Prediction speed:  20.40894736586007 fps
# Prediction speed:  20.001449690033382 fps
# Prediction speed:  18.86784915811587 fps
# Prediction speed:  20.000019073504518 fps
# Prediction speed:  19.231545885967126 fps
# Prediction speed:  19.230487788104003 fps
# Prediction speed:  20.00097279511695 fps
# Prediction speed:  19.2311931737422 fps
# Prediction speed:  20.407159990463725 fps
# Prediction speed:  17.857828945127558 fps
# Prediction speed:  18.868358427840732 fps
# Prediction speed:  19.9996376103262 fps
# Prediction speed:  19.60825600149599 fps
# Prediction speed:  19.23066412966232 fps
# Prediction speed:  19.61018121972658 fps
# Prediction speed:  18.86818866821116 fps
# Prediction speed:  18.517816698381022 fps
# Prediction speed:  19.606789422263358 fps
# Prediction speed:  20.000591295557175 fps
# Prediction speed:  18.866236652002986 fps
# Prediction speed:  18.869037496907122 fps
# Prediction speed:  18.5187978224108 fps
# Prediction speed:  18.520433260181306 fps
# total boxes:  19268
# imgs:  1100
