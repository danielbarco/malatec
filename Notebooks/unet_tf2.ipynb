# %% [markdown]
# # Nuclei Segmentation - UNet using Tensorflow 2

# %% [markdown]
# # Intro
# - Dataset used is from NIH ftp://lhcftp.nlm.nih.gov/Open-Access-Datasets/Malaria/NIH-NLM-ThinBloodSmearsPf/
# - The architecture used is [U-Net](https://arxiv.org/abs/1505.04597), which is very common for image segmentation problems such as this.
# - This notebook is inspired from the great kernel [Keras U-net starter - LB 0.277](https://www.kaggle.com/keegil/keras-u-net-starter-lb-0-277) by Kjetil Åmdal-Sævik.

# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from PIL import ImageFile

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, BatchNormalization
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K

import tensorflow as tf

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed
print(tf.__version__)
# Out:
# 2.3.1

# %%
os.getcwd()
# Out:
# '/Users/fight/Documents/Malaria/malatec/Notebooks'

# %%
# Set some parameters
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3
TRAIN_PATH = '../NIH-NLM-ThinBloodSmearsPf/Polygon Set/'
TEST_PATH = '../NIH-NLM-ThinBloodSmearsPf/Point Set/'
FINAL_TEST_PATH = '../NIH-NLM-ThinBloodSmearsPf/Point Set/'

#TRAIN_PATH = 'data/stage1_train/'
#TEST_PATH = 'data/stage1_test/'
#FINAL_TEST_PATH = 'data/stage2_test_final/'

dir_path = ''

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]
final_test_ids = next(os.walk(FINAL_TEST_PATH))[1]

# %% [markdown]
# # Get the data
# - Downsample both the training and test images to reduce computations
# - Retain record of the original sizes of the test images to upsample predicted masks and create correct run-length encodings

# %%
# Get and resize train images and masks
img_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
mask_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
# Out:
# Getting and resizing train images and masks ...

# %%
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    
    #Read image files iteratively
    path = TRAIN_PATH + id_
    img = imread(dir_path + path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    
    #Append image to numpy array for train dataset
    img_train[n] = img
    
    #Read corresponding mask files iteratively
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    
    #Looping through masks
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        
        #Read individual masks
        mask_ = imread(dir_path + path + '/masks/' + mask_file)
        
        #Expand individual mask dimensions
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        
        #Overlay individual masks to create a final mask for corresponding image
        mask = np.maximum(mask, mask_)
    
    #Append mask to numpy array for train dataset
    mask_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    
    #Read images iteratively
    img = imread(dir_path + path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    
    #Get test size
    sizes_test.append([img.shape[0], img.shape[1]])
    
    #Resize image to match training data
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    
    #Append image to numpy array for test dataset
    X_test[n] = img

print('Done!')
# Out:
# 100%|██████████| 670/670 [03:41<00:00,  3.02it/s]Getting and resizing test images ...
#
# 100%|██████████| 65/65 [00:01<00:00, 48.40it/s]Done!

# %% [markdown]
# ## Visualize imported data

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
imshow(img_train[ix])
plt.show()
imshow(np.squeeze(mask_train[ix]))
plt.show()

# %% [markdown]
# # Build and train our neural network
# Next we build our U-Net model, loosely based on [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/pdf/1505.04597.pdf) and very similar to [this repo](https://github.com/jocicmarko/ultrasound-nerve-segmentation) from the Kaggle Ultrasound Nerve Segmentation competition.
#
# ![](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (s)
c1 = BatchNormalization()(c1)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c1)
c1 = BatchNormalization()(c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p1)
c2 = BatchNormalization()(c2)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c2)
c2 = BatchNormalization()(c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p2)
c3 = BatchNormalization()(c3)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c3)
c3 = BatchNormalization()(c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p3)
c4 = BatchNormalization()(c4)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c4)
c4 = BatchNormalization()(c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p4)
c5 = BatchNormalization()(c5)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c5)
c5 = BatchNormalization()(c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u6)
c6 = BatchNormalization()(c6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c6)
c6 = BatchNormalization()(c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u7)
c7 = BatchNormalization()(c7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c7)
c7 = BatchNormalization()(c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u8)
c8 = BatchNormalization()(c8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c8)
c8 = BatchNormalization()(c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u9)
c9 = BatchNormalization()(c9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c9)
c9 = BatchNormalization()(c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

# %%
model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 128, 128, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 896         lambda[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 9248        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 512)    1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 512)    2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 512)    2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 512)    2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 128)  262272      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 384)  0           conv2d_transpose[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  884992      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  590080      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 64)   65600       batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 192)  0           conv2d_transpose_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  221312      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 128)  147584      dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 32)   16416       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 96)   0           conv2d_transpose_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 64)   55360       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 64)   36928       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 16) 4112        batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 48) 0           conv2d_transpose_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 32) 13856       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 32) 9248        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 1)  33          batch_normalization_17[0][0]
# ==================================================================================================
# Total params: 7,031,793
# Trainable params: 7,025,905
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
# Fit model
earlystopper = EarlyStopping(patience=15, verbose=1)
checkpointer = ModelCheckpoint('model_unet_checkpoint.h5', verbose=1, save_best_only=True)
results = model.fit(img_train, mask_train, validation_split=0.1, batch_size=16, epochs=100, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Epoch 1/100
# 38/38 [==============================] - ETA: 0s - loss: 0.3150 - accuracy: 0.8977
# Epoch 00001: val_loss improved from inf to 18.13948, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 73s 2s/step - loss: 0.3150 - accuracy: 0.8977 - val_loss: 18.1395 - val_accuracy: 0.2128
# Epoch 2/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1801 - accuracy: 0.9527
# Epoch 00002: val_loss improved from 18.13948 to 7.54782, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 74s 2s/step - loss: 0.1801 - accuracy: 0.9527 - val_loss: 7.5478 - val_accuracy: 0.2354
# Epoch 3/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1405 - accuracy: 0.9603
# Epoch 00003: val_loss improved from 7.54782 to 0.56277, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 73s 2s/step - loss: 0.1405 - accuracy: 0.9603 - val_loss: 0.5628 - val_accuracy: 0.7576
# Epoch 4/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9620
# Epoch 00004: val_loss improved from 0.56277 to 0.51395, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 73s 2s/step - loss: 0.1307 - accuracy: 0.9620 - val_loss: 0.5139 - val_accuracy: 0.8219
# Epoch 5/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1323 - accuracy: 0.9610
# Epoch 00005: val_loss improved from 0.51395 to 0.30791, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 73s 2s/step - loss: 0.1323 - accuracy: 0.9610 - val_loss: 0.3079 - val_accuracy: 0.8653
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9615
# Epoch 00006: val_loss improved from 0.30791 to 0.28887, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 76s 2s/step - loss: 0.1236 - accuracy: 0.9615 - val_loss: 0.2889 - val_accuracy: 0.8797
# Epoch 7/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.9609
# Epoch 00007: val_loss did not improve from 0.28887
# 38/38 [==============================] - 77s 2s/step - loss: 0.1190 - accuracy: 0.9609 - val_loss: 0.5541 - val_accuracy: 0.8537
# Epoch 8/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9650
# Epoch 00008: val_loss did not improve from 0.28887
# 38/38 [==============================] - 76s 2s/step - loss: 0.1050 - accuracy: 0.9650 - val_loss: 0.3502 - val_accuracy: 0.8677
# Epoch 9/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1051 - accuracy: 0.9640
# Epoch 00009: val_loss improved from 0.28887 to 0.19728, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 74s 2s/step - loss: 0.1051 - accuracy: 0.9640 - val_loss: 0.1973 - val_accuracy: 0.9256
# Epoch 10/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1029 - accuracy: 0.9637
# Epoch 00010: val_loss did not improve from 0.19728
# 38/38 [==============================] - 74s 2s/step - loss: 0.1029 - accuracy: 0.9637 - val_loss: 0.2596 - val_accuracy: 0.9001
# Epoch 11/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1029 - accuracy: 0.9654
# Epoch 00011: val_loss did not improve from 0.19728
# 38/38 [==============================] - 73s 2s/step - loss: 0.1029 - accuracy: 0.9654 - val_loss: 0.2091 - val_accuracy: 0.9239
# Epoch 12/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.9665
# Epoch 00012: val_loss improved from 0.19728 to 0.17196, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 75s 2s/step - loss: 0.0965 - accuracy: 0.9665 - val_loss: 0.1720 - val_accuracy: 0.9435
# Epoch 13/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0949 - accuracy: 0.9675
# Epoch 00013: val_loss did not improve from 0.17196
# 38/38 [==============================] - 72s 2s/step - loss: 0.0949 - accuracy: 0.9675 - val_loss: 0.1938 - val_accuracy: 0.9290
# Epoch 14/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9662
# Epoch 00014: val_loss improved from 0.17196 to 0.13951, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 71s 2s/step - loss: 0.0938 - accuracy: 0.9662 - val_loss: 0.1395 - val_accuracy: 0.9499
# Epoch 15/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9668
# Epoch 00015: val_loss improved from 0.13951 to 0.09728, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 72s 2s/step - loss: 0.0937 - accuracy: 0.9668 - val_loss: 0.0973 - val_accuracy: 0.9619
# Epoch 16/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9690
# Epoch 00016: val_loss did not improve from 0.09728
# 38/38 [==============================] - 73s 2s/step - loss: 0.0859 - accuracy: 0.9690 - val_loss: 0.1152 - val_accuracy: 0.9542
# Epoch 17/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9676
# Epoch 00017: val_loss improved from 0.09728 to 0.09241, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 73s 2s/step - loss: 0.0879 - accuracy: 0.9676 - val_loss: 0.0924 - val_accuracy: 0.9680
# Epoch 18/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0952 - accuracy: 0.9658
# Epoch 00018: val_loss improved from 0.09241 to 0.08996, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 72s 2s/step - loss: 0.0952 - accuracy: 0.9658 - val_loss: 0.0900 - val_accuracy: 0.9704
# Epoch 19/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.9681
# Epoch 00019: val_loss improved from 0.08996 to 0.08701, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 73s 2s/step - loss: 0.0880 - accuracy: 0.9681 - val_loss: 0.0870 - val_accuracy: 0.9669
# Epoch 20/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9683
# Epoch 00020: val_loss improved from 0.08701 to 0.07507, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 74s 2s/step - loss: 0.0858 - accuracy: 0.9683 - val_loss: 0.0751 - val_accuracy: 0.9720
# Epoch 21/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9695
# Epoch 00021: val_loss did not improve from 0.07507
# 38/38 [==============================] - 73s 2s/step - loss: 0.0820 - accuracy: 0.9695 - val_loss: 0.0819 - val_accuracy: 0.9707
# Epoch 22/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9687
# Epoch 00022: val_loss did not improve from 0.07507
# 38/38 [==============================] - 73s 2s/step - loss: 0.0839 - accuracy: 0.9687 - val_loss: 0.0762 - val_accuracy: 0.9709
# Epoch 23/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 0.9698
# Epoch 00023: val_loss did not improve from 0.07507
# 38/38 [==============================] - 73s 2s/step - loss: 0.0804 - accuracy: 0.9698 - val_loss: 0.0759 - val_accuracy: 0.9714
# Epoch 24/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9705
# Epoch 00024: val_loss improved from 0.07507 to 0.07211, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 74s 2s/step - loss: 0.0773 - accuracy: 0.9705 - val_loss: 0.0721 - val_accuracy: 0.9724
# Epoch 25/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9710
# Epoch 00025: val_loss did not improve from 0.07211
# 38/38 [==============================] - 73s 2s/step - loss: 0.0753 - accuracy: 0.9710 - val_loss: 0.0813 - val_accuracy: 0.9713
# Epoch 26/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9706
# Epoch 00026: val_loss did not improve from 0.07211
# 38/38 [==============================] - 73s 2s/step - loss: 0.0777 - accuracy: 0.9706 - val_loss: 0.0723 - val_accuracy: 0.9728
# Epoch 27/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9701
# Epoch 00027: val_loss did not improve from 0.07211
# 38/38 [==============================] - 73s 2s/step - loss: 0.0782 - accuracy: 0.9701 - val_loss: 0.0770 - val_accuracy: 0.9716
# Epoch 28/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9708
# Epoch 00028: val_loss did not improve from 0.07211
# 38/38 [==============================] - 2263s 60s/step - loss: 0.0760 - accuracy: 0.9708 - val_loss: 0.0817 - val_accuracy: 0.9704
# Epoch 29/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0742 - accuracy: 0.9709
# Epoch 00029: val_loss did not improve from 0.07211
# 38/38 [==============================] - 246s 6s/step - loss: 0.0742 - accuracy: 0.9709 - val_loss: 0.0820 - val_accuracy: 0.9707
# Epoch 30/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9719
# Epoch 00030: val_loss did not improve from 0.07211
# 38/38 [==============================] - 220s 6s/step - loss: 0.0731 - accuracy: 0.9719 - val_loss: 0.0725 - val_accuracy: 0.9732
# Epoch 31/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9718
# Epoch 00031: val_loss improved from 0.07211 to 0.07168, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 212s 6s/step - loss: 0.0718 - accuracy: 0.9718 - val_loss: 0.0717 - val_accuracy: 0.9733
# Epoch 32/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9712
# Epoch 00032: val_loss improved from 0.07168 to 0.06930, saving model to model_unet_checkpoint.h5
# 38/38 [==============================] - 2682s 71s/step - loss: 0.0730 - accuracy: 0.9712 - val_loss: 0.0693 - val_accuracy: 0.9733
# Epoch 33/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9707
# Epoch 00033: val_loss did not improve from 0.06930
# 38/38 [==============================] - 76s 2s/step - loss: 0.0753 - accuracy: 0.9707 - val_loss: 0.0733 - val_accuracy: 0.9737
# Epoch 34/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9720
# Epoch 00034: val_loss did not improve from 0.06930
# 38/38 [==============================] - 77s 2s/step - loss: 0.0715 - accuracy: 0.9720 - val_loss: 0.0797 - val_accuracy: 0.9725
# Epoch 35/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9723
# Epoch 00035: val_loss did not improve from 0.06930
# 38/38 [==============================] - 75s 2s/step - loss: 0.0708 - accuracy: 0.9723 - val_loss: 0.0738 - val_accuracy: 0.9738
# Epoch 36/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9727
# Epoch 00036: val_loss did not improve from 0.06930
# 38/38 [==============================] - 74s 2s/step - loss: 0.0690 - accuracy: 0.9727 - val_loss: 0.0730 - val_accuracy: 0.9734
# Epoch 37/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9723
# Epoch 00037: val_loss did not improve from 0.06930
# 38/38 [==============================] - 70s 2s/step - loss: 0.0699 - accuracy: 0.9723 - val_loss: 0.0744 - val_accuracy: 0.9733
# Epoch 38/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9711
# Epoch 00038: val_loss did not improve from 0.06930
# 38/38 [==============================] - 70s 2s/step - loss: 0.0739 - accuracy: 0.9711 - val_loss: 0.0761 - val_accuracy: 0.9730
# Epoch 39/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9720
# Epoch 00039: val_loss did not improve from 0.06930
# 38/38 [==============================] - 72s 2s/step - loss: 0.0712 - accuracy: 0.9720 - val_loss: 0.0762 - val_accuracy: 0.9729
# Epoch 40/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0716 - accuracy: 0.9721
# Epoch 00040: val_loss did not improve from 0.06930
# 38/38 [==============================] - 74s 2s/step - loss: 0.0716 - accuracy: 0.9721 - val_loss: 0.0716 - val_accuracy: 0.9732
# Epoch 41/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0685 - accuracy: 0.9726
# Epoch 00041: val_loss did not improve from 0.06930
# 38/38 [==============================] - 112s 3s/step - loss: 0.0685 - accuracy: 0.9726 - val_loss: 0.0699 - val_accuracy: 0.9738
# Epoch 42/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9729
# Epoch 00042: val_loss did not improve from 0.06930
# 38/38 [==============================] - 117s 3s/step - loss: 0.0676 - accuracy: 0.9729 - val_loss: 0.0722 - val_accuracy: 0.9737
# Epoch 43/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9730
# Epoch 00043: val_loss did not improve from 0.06930
# 38/38 [==============================] - 119s 3s/step - loss: 0.0675 - accuracy: 0.9730 - val_loss: 0.0711 - val_accuracy: 0.9733
# Epoch 44/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9732
# Epoch 00044: val_loss did not improve from 0.06930
# 38/38 [==============================] - 119s 3s/step - loss: 0.0673 - accuracy: 0.9732 - val_loss: 0.0715 - val_accuracy: 0.9733
# Epoch 45/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9737
# Epoch 00045: val_loss did not improve from 0.06930
# 38/38 [==============================] - 115s 3s/step - loss: 0.0656 - accuracy: 0.9737 - val_loss: 0.0718 - val_accuracy: 0.9739
# Epoch 46/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9735
# Epoch 00046: val_loss did not improve from 0.06930
# 38/38 [==============================] - 118s 3s/step - loss: 0.0656 - accuracy: 0.9735 - val_loss: 0.1076 - val_accuracy: 0.9597
# Epoch 47/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9727
# Epoch 00047: val_loss did not improve from 0.06930
# 38/38 [==============================] - 117s 3s/step - loss: 0.0687 - accuracy: 0.9727 - val_loss: 0.0705 - val_accuracy: 0.9734
# Epoch 00047: early stopping

# %% [markdown]
# # Make predictions

# %%
# Predict on train, val and test
model = load_model('model_unet_checkpoint.h5')
preds_train = model.predict(img_train[:int(img_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(img_train[int(img_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test_t)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test_t[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 19/19 [==============================] - 27s 1s/step
# 3/3 [==============================] - 2s 554ms/step
# 3/3 [==============================] - 2s 540ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_test_t))
imshow(img_train[ix])
plt.show()
imshow(np.squeeze(mask_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(img_train[int(img_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(mask_train[int(mask_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()

# %% [markdown]
# # Encode and submit our results
#
# - [Link](https://www.kaggle.com/rakhlin/fast-run-length-encoding-python) has an excellent implementation of run-length encoding.

# %%
# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def prob_to_rles(x, cutoff=0.5):
    lab_img = label(x > cutoff)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %% [markdown]
# - Iterate over the test IDs and generate run-length encodings for each seperate mask identified by skimage ...

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids):
    rle = list(prob_to_rles(preds_test_upsampled[n]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

# %% [markdown]
# - Create submission

# %%
# Create submission DataFrame
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-1.csv', index=False)
