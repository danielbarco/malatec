# %% [markdown]
# # Focus Stacking Fast

# %% [markdown]
# Using focus-stack to stack different pictures to one stacked version https://github.com/momonala/focus-stack
#
# The code does not work consistently and throws some errors so we adapted the focus_stack.py with a try, except. This is definitely not the best of all solutions.

# %%
import os
from focus_stack import FocusStacker
import matplotlib.pyplot as plt
import cv2

# %%
cv2.__version__
# Out:
# '4.4.0'

# %%
stacker = FocusStacker(
        laplacian_kernel_size=5, gaussian_blur_kernel_size=5
    )

# %%
directories = ['../stacking/stack_img_1', '../stacking/stack_img_2', '../stacking/stack_img_3', '../stacking/stack_img_4']
for directory in directories:
    image_files = []
    for filename in os.listdir(directory):
        if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
            image_files.append(os.path.join(directory, filename))
        else:
            continue
    image_files.sort()
    
    stacked = stacker.focus_stack(image_files)
    cv2.imwrite(f'../stacking/plot{directory[-1]}.png', stacked)
# Out:
# INFO:focus_stack:reading images
# INFO:focus_stack:aligning images
# INFO:focus_stack:Computing the laplacian of the blurred images
# INFO:focus_stack:Using laplacian gradient to find regions of focus, and stack.
# INFO:focus_stack:reading images
# INFO:focus_stack:aligning images
# INFO:focus_stack:Computing the laplacian of the blurred images
# INFO:focus_stack:Using laplacian gradient to find regions of focus, and stack.
# INFO:focus_stack:reading images
# INFO:focus_stack:aligning images
# ERROR:focus_stack:OpenCV(4.4.0) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-4jcifzim/opencv/modules/imgproc/src/imgwarp.cpp:3167: error: (-215:Assertion failed) (M0.type() == CV_32F || M0.type() == CV_64F) && M0.rows == 3 && M0.cols == 3 in function 'warpPerspective'
# Traceback (most recent call last):
#   File "/Users/fight/Documents/Malaria/malatec/Notebooks/focus_stack.py", line 122, in _align_images
#     flags=cv2.INTER_LINEAR,
# ...

# %%
plt.imshow(stacked)

# %%
directory = '../stacking/stack_img_1'
image_files = []
for filename in os.listdir(directory):
    if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
        image_files.append(os.path.join(directory, filename))
    else:
        continue
image_files.sort()
img1 = 


img1_key_points, image1_desc = detector.detectAndCompute(img1, None)
img_i_key_points, image_i_desc = detector.detectAndCompute(img2, None)
bf = cv2.BFMatcher()
# This returns the top two matches for each feature point (list of list)
pair_matches = bf.knnMatch(image_i_desc, image1_desc, k=2)
raw_matches = []
for m, n in pair_matches:
    if m.distance < 0.7 * n.distance:
        raw_matches.append(m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-06b8c1df73d4> in <module>
#       9
#      10
# ---> 11 img1_key_points, image1_desc = detector.detectAndCompute(img1, None)
#      12 img_i_key_points, image_i_desc = detector.detectAndCompute(img2, None)
#      13 bf = cv2.BFMatcher()
#
# NameError: name 'detector' is not defined

# %% [markdown]
# Using C++ implementation of focus-stacking https://github.com/wojtasso/focus-stacking

# %%
# !git clone https://github.com/wojtasso/focus-stacking.git
# Out:
# Cloning into 'focus-stacking'...
# remote: Enumerating objects: 71, done.
# remote: Total 71 (delta 0), reused 0 (delta 0), pack-reused 71
# Unpacking objects: 100% (71/71), done.

# %%
# !apt install cmake g++ make -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# make is already the newest version (4.1-9.1ubuntu1).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# g++ is already the newest version (4:7.4.0-1ubuntu2.3).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %%
# !cd focus-stacking cmake . make ./focus

# %%
# !./focus
# Out:
# /bin/sh: 1: ./focus: not found
